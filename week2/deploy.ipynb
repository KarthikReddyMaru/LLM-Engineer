# %%
# !uv run modal deploy Location.py

# %% [markdown]
# # Remote run

# %%
import modal

location = modal.Cls.from_name(app_name = 'Location', name = 'Location')

# %%
location().getLocation.remote()

# %% [markdown]
# # Local run

# %%
from Location import app, Location

# %%
with app.run():
    loc = Location()
    print(loc.getLocation.remote())
